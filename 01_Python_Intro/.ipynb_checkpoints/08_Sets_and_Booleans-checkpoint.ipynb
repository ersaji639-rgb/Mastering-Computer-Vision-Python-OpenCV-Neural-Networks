# %% [markdown]
# ##### Sets

# %%
x = set()

# %%
x
# Out:
# set()

# %%
type(x)
# Out:
# set

# %%
x.add(1)

# %%
x
# Out:
# {1}

# %%
x.add(2)

# %%
x
# Out:
# {1, 2}

# %%
x.add(4)

# %%
x
# Out:
# {1, 2, 4}

# %%
x.add(1)

# %%
x
# Out:
# {1, 2, 4}

# %%
x.add('1')

# %%
x
# Out:
# {1, '1', 2, 4}

# %%
l1 = [1,2,3,1,2,2,1,3,1,3,1,3,45,5,2,4,5,2,2,4,5,6,11,110,22,330,'hi','hello','hi']

# %%
set(l1)
# Out:
# {1, 11, 110, 2, 22, 3, 330, 4, 45, 5, 6, 'hello', 'hi'}

# %% [markdown]
# ###### Booleans

# %%
a = True

# %%
a
# Out:
# True

# %%
x = 5 > 8

# %%
x
# Out:
# False

# %%
type(x)
# Out:
# bool

# %% [markdown]
# ###### Comparison Operators

# %%
#Equal 
2 == 2
# Out:
# True

# %%
1 == 1
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
#Not Equal

2 != 2
# Out:
# False

# %%
2 != 9/3
# Out:
# True

# %%
1 != 21
# Out:
# True

# %%
#greater than
2 > 1
# Out:
# True

# %%
4 >= 8/2
# Out:
# True

# %%
4 > 9
# Out:
# False

# %%
#less than

2 <= 9
# Out:
# True

# %% [markdown]
# ###### Chained Comparison Operator

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 < 3 > 2
# Out:
# True

# %%
1 < 3 and 3 < 2
# Out:
# False

# %%
1 < 2 or 2 < 3
# Out:
# True

# %%
1 < 2 or 2 > 3
# Out:
# True

# %%
1 > 2 or 2 < 3
# Out:
# True

# %%
1 > 2 or 2 > 3
# Out:
# False
