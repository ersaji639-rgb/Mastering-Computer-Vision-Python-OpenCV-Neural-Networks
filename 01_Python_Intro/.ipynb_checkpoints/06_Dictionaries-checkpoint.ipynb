# %%
my_dict = {'k1':'v1','k2':'value2'}

# %%
my_dict['k1']
# Out:
# 'v1'

# %%
my_dict['k2']
# Out:
# 'value2'

# %%
d1 = {'a1':123,
     'b1':[11,32,43],
     'c1':['item1','item2',12.54,['shreyas','hi']],
     'd1':'Hi I am here'}

# %%
d1['a1']
# Out:
# 123

# %%
len(d1['d1'])
# Out:
# 12

# %%
d1['a1']/len(d1['d1'])
# Out:
# 10.25

# %%
d1['c1'][-1][-1].upper()+' '+d1['c1'][-1][-2]
# Out:
# 'HI shreyas'

# %%
d1['c1'] = 821649823

# %%
d1
# Out:
# {'a1': 123, 'b1': [11, 32, 43], 'c1': 821649823, 'd1': 'Hi I am here'}

# %%
l1 = []

# %%
l1.append(34)

# %%
l1
# Out:
# [34]

# %%
d = {}

# %%
d['animal'] = 'Cat'

# %%
d
# Out:
# {'animal': 'Cat'}

# %%
d['numbers'] = [1,2,3,4,45,5]

# %%
d
# Out:
# {'animal': 'Cat', 'numbers': [1, 2, 3, 4, 45, 5]}

# %%
d['nested'] = {'key1':3749,'key2':['kjd','jadk',342]}

# %%
d
# Out:
# {'animal': 'Cat',
#  'numbers': [1, 2, 3, 4, 45, 5],
#  'nested': {'key1': 3749, 'key2': ['kjd', 'jadk', 342]}}

# %%
d['nested']['key1']
# Out:
# 3749

# %%
d['nested']['key2'][-1]
# Out:
# 342

# %% [markdown]
# #### Dictionary Methods

# %%
sample_dict = {'key1':1,
               'key2':2,
               'key3':3}

# %%
#method to return a list of keys

sample_dict.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
type(sample_dict.keys())
# Out:
# dict_keys

# %%
int('567')
# Out:
# 567

# %%
list(sample_dict.keys())
# Out:
# ['key1', 'key2', 'key3']

# %%
#method to return a list of values

sample_dict.values()
# Out:
# dict_values([1, 2, 3])

# %%
#Method to return tuples of all the items

sample_dict.items()
# Out:
# dict_items([('key1', 1), ('key2', 2), ('key3', 3)])
