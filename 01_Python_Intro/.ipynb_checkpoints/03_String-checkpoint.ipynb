# %% [markdown]
# ### Creating a sring :

# %%
# Single word :
'hello'
# Out:
# 'hello'

# %%
"Hai man!"
# Out:
# 'Hai man!'

# %%
'Hai man'
# Out:
# 'Hai man'

# %%
"I can't is not a solution "
# Out:
# "I can't is not a solution "

# %% [markdown]
# ### Printing a String:

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
"Hello 1"
"Hello 2"
# Out:
# 'Hello 2'

# %%
print("Hello 1")
"Hello 2"
# Out:
# Hello 1
# 'Hello 2'

# %%
print("Hello 1")
print("Hello 2")
# Out:
# Hello 1
# Hello 2

# %%
print("Hello 1\nHello 2")
# Out:
# Hello 1
# Hello 2
