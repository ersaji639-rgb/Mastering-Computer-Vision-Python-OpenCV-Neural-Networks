# %% [markdown]
# #### Basic Arithmetic

# %%
#addition
3+5
# Out:
# 8

# %%
#subtraction
12-3
# Out:
# 9

# %%
#multiplicaiton
3*34
# Out:
# 102

# %%
# Division
4/2
# Out:
# 2.0

# %%
#Floor Division
10//4
# Out:
# 2

# %%
#Modulo
7%4
# Out:
# 3

# %%
100%13
# Out:
# 9

# %%
#Power
4**2
# Out:
# 16

# %%
4**0.5
# Out:
# 2.0

# %%
125**(1/3)
# Out:
# 4.999999999999999

# %% [markdown]
# ###### Order of Operations

# %%
2+10*10+4
# Out:
# 106

# %%
(2+10)*(10+4)
# Out:
# 168
