# %%
my_list = [1,2,3,4,5]

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
type(my_list)
# Out:
# list

# %%
my_list = ['Mumbai',23,100.67,'45']

# %%
len('hello')
# Out:
# 5

# %%
len(my_list)
# Out:
# 4

# %% [markdown]
# ###### Indexing and slicing

# %%
my_list[0]
# Out:
# 'Mumbai'

# %%
v1 = my_list[-4]

# %%
v1
# Out:
# 'Mumbai'

# %%
type(v1)
# Out:
# str

# %%
v1.upper()
# Out:
# 'MUMBAI'

# %%
v1[:-3]
# Out:
# 'Mum'

# %%
my_list
# Out:
# ['Mumbai', 23, 100.67, '45']

# %%
my_list[-2]/my_list[-3]
# Out:
# 4.376956521739131

# %%
my_list[1:3]
# Out:
# [23, 100.67]

# %%
l1 = ['virat','sachin',12,'hi',45.87,['nested list', 23, 100],'hello']

# %%
l1[-2][2]/l1[2]
# Out:
# 8.333333333333334

# %%
100/12
# Out:
# 8.333333333333334

# %%
dataset = [
10.5,
[23, "ML", ["AI", {"x": "iHUB", "y": 404}]],
"Shreyas",
(99, "Stanford", [3.14, "Research"]),
{"a": 1, "b": [True, False, "Deep Learning"]},
["GPT", (2025, {"topic": "LLM", "score": 98.7})],
False,
("Vision", {"lab": "RBPL", "course": ["AI", "ML", "DL"]}),
13
]

# %% [markdown]
# prac_list = [12.3,[45.6,['hello at IIT Roorkee']], '45', 98, 'iHUB', ['Steve Jobs'], 'works', 32, ' ']
#
# 1. 12.3 + 98
# 2. 'Steve Jobs works at iHUB'
# 3. replace 32 by 'your name' (Shreyas)
# 4. 'hello Shreyas'
#
#
# prac_list2 = [[98,[34.8,['hello world']],'Elon',[['Musk'],'Shreyas']], 'controls', ' ',404, 747]
#
# 1. 'HELLO Elon Musk'
# 2. do a division of any two numbers from prac_list2 and mulitply it with addition of other two numbers
# 3. replace 'Shreyas' with 'everyone'
# 4. 'Elon Musk controls everyone'

# %%
prac_list2 = [[98,[34.8,['hello world']],'Elon',[['Musk'],'Shreyas']], 'controls', ' ',404, 747]

# %%
#3
prac_list2[0][-1][-1] = 'everyone'

# %%
prac_list2
# Out:
# [[98, [34.8, ['hello world']], 'Elon', [['Musk'], 'everyone']],
#  'controls',
#  ' ',
#  404,
#  747]

# %%
#4
prac_list2[0][2]+prac_list2[-3]+prac_list2[-4]+prac_list2[-3]+prac_list2[0][-1][-1]
# Out:
# 'Elon controls everyone'

# %%
dataset
# Out:
# [10.5,
#  [23, 'ML', ['AI', {'x': 'iHUB', 'y': 404}]],
#  'Shreyas',
#  (99, 'Stanford', [3.14, 'Research']),
#  {'a': 1, 'b': [True, False, 'Deep Learning']},
#  ['GPT', (2025, {'topic': 'LLM', 'score': 98.7})],
#  False,
#  ('Vision', {'lab': 'RBPL', 'course': ['AI', 'ML', 'DL']}),
#  13]

# %%
dataset[0]+dataset[1][0]
# Out:
# 33.5

# %% [markdown]
# ###### Concatenation

# %%
['hi',1,2,3]+['hi']+prac_list2[0]
# Out:
# ['hi',
#  1,
#  2,
#  3,
#  'hi',
#  98,
#  [34.8, ['hello world']],
#  'Elon',
#  [['Musk'], 'everyone']]

# %%
prac_list2[0][1:3]
# Out:
# [[34.8, ['hello world']], 'Elon']

# %%
my_list+prac_list2[0][1:3]
# Out:
# ['Mumbai', 23, 100.67, '45', [34.8, ['hello world']], 'Elon']

# %%
my_list = my_list+[1,2]

# %%
my_list
# Out:
# ['Mumbai', 23, 100.67, '45', 1, 2]

# %% [markdown]
# ###### Basic List Methods

# %%
l1
# Out:
# ['virat', 'sachin', 12, 'hi', 45.87, ['nested list', 23, 100], 'hello']

# %%
#append
l1.append('new item')

# %%
l1
# Out:
# ['virat',
#  'sachin',
#  12,
#  'hi',
#  45.87,
#  ['nested list', 23, 100],
#  'hello',
#  'new item']

# %%
#pop
l1.pop()
# Out:
# 'new item'

# %%
l1
# Out:
# ['virat', 'sachin', 12, 'hi', 45.87, ['nested list', 23, 100], 'hello']

# %%
l1.pop()
# Out:
# 'hello'

# %%
l1
# Out:
# ['virat', 'sachin', 12, 'hi', 45.87, ['nested list', 23, 100]]

# %%
l1.pop(3)
# Out:
# 'hi'

# %%
l1
# Out:
# ['virat', 'sachin', 12, 45.87, ['nested list', 23, 100]]

# %%
#reverse
l1.reverse()

# %%
l1
# Out:
# [['nested list', 23, 100], 45.87, 12, 'sachin', 'virat']

# %%
new = ['a','e','x','c','d']

# %%
new.reverse()

# %%
new
# Out:
# ['d', 'c', 'x', 'e', 'a']

# %%
new.sort()

# %%
new
# Out:
# ['a', 'c', 'd', 'e', 'x']

# %%
num = [1,32,5,4,2,3,8,56,101,342,99]

# %%
num.sort(reverse=True)

# %%
num
# Out:
# [342, 101, 99, 56, 32, 8, 5, 4, 3, 2, 1]

# %%
l2 = [1,2,'hi',3,4,1,2,3,1,2,3,1,31,3,5,6,78,2,2,'hi',1245,1]

# %%
#count
l2.count(1)
# Out:
# 5

# %%
l2.count('hi')
# Out:
# 2

# %%
x = [1,2,3]

# %%
#append
x.append([4,5])

# %%
x
# Out:
# [1, 2, 3, [4, 5]]

# %%
y = [1,2,3]

# %%
#extend
y.extend([4,5])

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
y
# Out:
# [1, 2, 3, 4, 5]

# %%
#insert
y.insert(3,'inserted item')

# %%
y.extend([2,3,2])

# %%
y
# Out:
# [1, 2, 3, 'inserted item', 4, 5, 2, 3, 2]

# %%
#remove
y.remove(3)

# %%
y
# Out:
# [1, 2, 'inserted item', 4, 5, 2, 3, 2]

# %% [markdown]
# ###### Nestes Lists

# %%
mat = [[1,2,3],
      [4,5,6],
       [7,8,9]]

# %%
mat
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
len(mat)
# Out:
# 3

# %%
mat[1][1]
# Out:
# 5

# %%
mat[2][-3]
# Out:
# 7

# %%
l1 = [1,100,2,3,4,57]
l1.sort()

# %%
l1
# Out:
# [1, 2, 3, 4, 57, 100]

# %%
l1.sort(reverse = True)

# %%
l1
# Out:
# [100, 57, 4, 3, 2, 1]
