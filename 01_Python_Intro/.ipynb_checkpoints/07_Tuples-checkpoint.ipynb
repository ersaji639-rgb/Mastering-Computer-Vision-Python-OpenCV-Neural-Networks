# %%
t = (1,2,3,4,5,6,7,'hi','hello','kjasbk')

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 10

# %%
t[3]
# Out:
# 4

# %%
t[3:6]
# Out:
# (4, 5, 6)

# %% [markdown]
# ###### Immutability

# %%
t[4] = 'change'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 t[4] = 'change'
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.append(23)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 t.append(23)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1 = (1,2,3,'hi','hello',2,6,2,3,4)

# %%
t1.count(2)
# Out:
# 3
