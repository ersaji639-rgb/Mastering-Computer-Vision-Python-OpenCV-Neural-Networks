# %% [markdown]
# ### Creating a sring :

# %%
# Single word :
'hello'
# Out:
# 'hello'

# %%
"Hai man!"
# Out:
# 'Hai man!'

# %%
'Hai man'
# Out:
# 'Hai man'

# %%
"I can't is not a solution "
# Out:
# "I can't is not a solution "

# %% [markdown]
# ### Printing a String:

# %%
"Hello World"
# Out:
# 'Hello World'

# %%
"Hello 1"
"Hello 2"
# Out:
# 'Hello 2'

# %%
print("Hello 1")
"Hello 2"
# Out:
# Hello 1
# 'Hello 2'

# %%
print("Hello 1")
print("Hello 2")
# Out:
# Hello 1
# Hello 2

# %%
print("Hello 1\nHello 2")
# Out:
# Hello 1
# Hello 2

# %% [markdown]
# * Note this is not an output cell:

# %% [markdown]
# #### Length of the string (including the spaces)

# %%
len('Saji M')
# Out:
# 6

# %% [markdown]
# #### String indexing:
# * sequence of characters, hence indexable

# %%
s = "Hello World "

# %%
s[0]
# Out:
# 'H'

# %%
s[-1]
# Out:
# ' '

# %%
len(s) # Number of characters.
# Out:
# 12

# %%
s[-12]
# Out:
# 'H'

# %%
type(s)
# Out:
# str

# %% [markdown]
# #### Slicing:

# %%
s = "Hello World"

# %%
len(s)
# Out:
# 11

# %%
s[0:5]
# Out:
# 'Hello'

# %%
s[-5::]
# Out:
# 'World'

# %%
s[:5]
# Out:
# 'Hello'

# %%
print(s)
# Out:
# Hello World

# %%
s[0:6]
# Out:
# 'Hello '

# %%
#[start:end+1:stepsize]

# %%
s[0:6:2]
# Out:
# 'Hlo'

# %%
s[-5::]
# Out:
# 'World'

# %%
s
# Out:
# 'Hello World'

# %% [markdown]
# * Reverse

# %%
s[::-1]
# Out:
# 'dlroW olleH'

# %%
#del input

# %%
# Check palindrome:
num = input("Enter a string: ")
if num == num[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Enter a string:  saji
# Not a palindrome

# %% [markdown]
# #### string properties (a. Immutability)

# %%
s = 'hello'

# %%
s[0]
# Out:
# 'h'

# %%
s[0] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 s[0] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %%
l1 = [1,2,3,'Saji', 'M']

# %%
l1[0]
# Out:
# 1

# %%
l1[1] = 21

# %%
l1
# Out:
# [1, 21, 3, 'Saji', 'M']

# %%
l1[-2]
# Out:
# 'Saji'

# %%
l1[-2][1]
# Out:
# 'a'

# %%
l1[-2][1] = 'x'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 l1[-2][1] = 'x'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# #### b. Concatenation

# %%
s1 = "Hai"
s2 = " "
s3 = "Saji M"

# %%
s4 = s1 + s2 + s3 
print(s4)
# Out:
# Hai Saji M

# %%
print('2' + '4')
# Out:
# 24

# %%
s3[::-2]
# Out:
# 'Mia'

# %% [markdown]
# ### Multiply :

# %%
s3
# Out:
# 'Saji M'

# %%
print(s3*2)
# Out:
# Saji MSaji M

# %%
a = '3'

# %%
a*3
# Out:
# '333'

# %% [markdown]
# ####  Basic built string Methods:
# * Takes input parameters as arguments.

# %%
# Upper case :
s = 'Hai Saji!'

# %%
s.upper()
# Out:
# 'HAI SAJI!'

# %%
s
# Out:
# 'Hai Saji!'

# %%
s.lower()
# Out:
# 'hai saji!'

# %%
# Split
s
# Out:
# 'Hai Saji!'

# %%
s.split() # Default by blank spaces  and convert it in to list
# Out:
# ['Hai', 'Saji!']

# %%
s
# Out:
# 'Hai Saji!'

# %%
s.split('a')
# Out:
# ['H', 'i S', 'ji!']

# %%
s
# Out:
# 'Hai Saji!'

# %%
# Capitalize 
s.capitalize()
# Out:
# 'Hai saji!'

# %%
# Count
s.count('s')
# Out:
# 0

# %%
s.count('S')
# Out:
# 1

# %%
s
# Out:
# 'Hai Saji!'

# %%
# Find 
s.find('a')
# Out:
# 1

# %%
s.find('ai')
# Out:
# 1

# %% [markdown]
#  ### is check method

# %%
s1 = "Hai Saji "
s1.isalnum()
# Out:
# False

# %%
s1 = "Hai Saji1"
s1.isalnum()
# Out:
# False

# %%
s1 = "HaiSaji "
s1.isalnum()
# Out:
# False

# %%
s1 = "HaiSaji2"
s1.isalnum()
# Out:
# True

# %%
s1 = "HaiSaji"
s1.isalnum()
# Out:
# True

# %%
s1.islower()
# Out:
# False

# %%
s1.isupper()
# Out:
# False

# %%
s1.isspace()
# Out:
# False

# %%
s1
# Out:
# 'HaiSaji'

# %%
s1.istitle()
# Out:
# False

# %%
s1.capitalize()
# Out:
# 'Haisaji'

# %%
A= 'Saji M'  
A.istitle() # Checks the first letter of every word
# Out:
# True

# %%
s1 = 'Hai Saji You are learning slowly but consistently'

# %%
s1.split('a')
# Out:
# ['H', 'i S', 'ji You ', 're le', 'rning slowly but consistently']

# %%
s1.partition('a') # We will get as a tuple , it only looks into the first occurance
# Out:
# ('H', 'a', 'i Saji You are learning slowly but consistently')

# %% [markdown]
# #### Print formatting
