# %%
if 40 > 2:
    print("True")
# Out:
# True

# %%
x = 54 <100
if x:
    print("Hai")
# Out:
# Hai

# %%
if len("Saji M") == 6:
    print("Good Morning")
# Out:
# Good Morning

# %%
loc = input("Enter you country").upper()  # loc = loc.capitalize()
#type(loc)
if loc == "INDIA" or "mumbai":
    print("Hello India")
elif loc == "SPAIN":
    print("Hello {}".format(loc))
else:
    print("Where are you?")
# Out:
# Enter you country d
# Hello India

# %% [markdown]
# * Above has issue mumbai is alsways saisfied:

# %%
loc = input("Enter your country: ").upper()

if loc == "INDIA" or loc == "MUMBAI":
    print("Hello India")
elif loc == "SPAIN":
    print("Hello {}".format(loc))
else:
    print("Where are you?")
# Out:
# Enter your country:  s
# Where are you?

# %%
a = 'Saji M'
a.isalpha()  # space is also not an alpha nuberic
# Out:
# False

# %% [markdown]
# ##### Alternatively

# %%
loc = input("Enter your location:")
if loc.upper() in ("INDIA", "MUMBAI"):
    print("Hello India")
# Out:
# Enter your location: h

# %%
a = 'saji M'
a.capitalize() # only first
print(a)
# Out:
# saji M
