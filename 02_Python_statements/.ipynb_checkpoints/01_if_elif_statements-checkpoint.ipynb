# %%
if 40 > 2:
    print("True")
# Out:
# True

# %%
x = 54 <100
if x:
    print("Hai")
# Out:
# Hai

# %%
if len("Saji M") == 6:
    print("Good Morning")
# Out:
# Good Morning

# %%
loc = input("Enter you country").upper()
if loc == "INDIA":
    print("Hello India")
elif loc == "SPAIN":
    print("Hello {}".format(loc))
else:
    print("Where are you?")
# Out:
# Enter you country spain
# Hello SPAIN
