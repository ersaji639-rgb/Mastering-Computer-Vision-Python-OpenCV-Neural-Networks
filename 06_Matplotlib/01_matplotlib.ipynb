# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
x = np.arange(10)

# %%
y = 2*x

# %%
plt.plot(x,y) 
plt.xlabel('X')
plt.ylabel('Y')
plt.xlim(2,7)
plt.ylim(2,10)
plt.title('Figure')
plt.show() 
plt.savefig('Sample_fig.png')
