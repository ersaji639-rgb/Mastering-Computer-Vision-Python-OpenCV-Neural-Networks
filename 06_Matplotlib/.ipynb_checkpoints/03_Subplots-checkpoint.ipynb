# %%
import numpy as np 
import matplotlib.pyplot as plt

# %%
a = np.linspace(0,10,11)
b = a**2

# %%
x = np.arange(10)
y = np.sqrt(x)

# %%
fig, axes = plt.subplots() # default one fig

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(axes)
# Out:
# matplotlib.axes._axes.Axes

# %%
fig, axes = plt.subplots(nrows= 1, ncols=2)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes.shape
# Out:
# (2,)

# %%
fig2, axes = plt.subplots(nrows= 2, ncols=2)

# %%
type(fig2)
# Out:
# matplotlib.figure.Figure

# %%
type(axes)
# Out:
# numpy.ndarray

# %%
axes
# Out:
# array([[<Axes: >, <Axes: >],
#        [<Axes: >, <Axes: >]], dtype=object)

# %%
axes.shape
# Out:
# (2, 2)

# %%
fig2, axes2 = plt.subplots()

# use axes object to add plot 
axes2.plot(x,y,'red') 
axes2.set_title('x vs y')
plt.show()

# %%
fig1, axes1 = plt.subplots(nrows= 1, ncols = 2) 
for ax in axes1:
    ax.plot(x,y)
    x = x**3
    y = y*19

# %%
axes1
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
axes.shape
# Out:
# (2, 2)

# %%
fig, axes1 = plt.subplots(nrows=1, ncols=2)
axes1[0].plot(a,b)
axes1[-1].plot(b,a)

# %%
fig, axes = plt.subplots(nrows=2, ncols=2)

axes[0, 1].plot(a, b)
axes[0, 1].set_xlabel('x2')
axes[0, 1].set_ylabel('y2')
axes[0, 1].set_title('plot1')

axes[1, 0].plot(a, b**0.2)

fig.suptitle('Figure level title', fontsize=10)
fig.supxlabel('X')
fig.supylabel('Y')


#fig.subplots_adjust(left=5, right=2)



plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for suptitle

plt.savefig('Sample3.png')  # save before showing
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[83], line 15
#      11 fig.supxlabel('X')
#      12 fig.supylabel('Y')
# ---> 15 fig.subplots_adjust(left=5, right=2)
#      19 plt.tight_layout(rect=[0, 0, 1, 0.95])  # leave space for suptitle
#      21 plt.savefig('Sample3.png')  # save before showing
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/figure.py:1294, in FigureBase.subplots_adjust(self, left, bottom, right, top, wspace, hspace)
#    1289     _api.warn_external(
#    1290         "This figure was using a layout engine that is "
#    1291         "incompatible with subplots_adjust and/or tight_layout; "
#    1292         "not calling subplots_adjust.")
#    1293     return
# -> 1294 self.subplotpars.update(left, bottom, right, top, wspace, hspace)
#    1295 for ax in self.axes:
#    1296     if ax.get_subplotspec() is not None:
#
# File ~/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py:773, in SubplotParams.update(self, left, bottom, right, top, wspace, hspace)
#     768 """
#     769 Update the dimensions of the passed parameters. *None* means unchanged.
#     770 """
#     771 if ((left if left is not None else self.left)
#     772         >= (right if right is not None else self.right)):
# --> 773     raise ValueError('left cannot be >= right')
#     774 if ((bottom if bottom is not None else self.bottom)
#     775         >= (top if top is not None else self.top)):
#     776     raise ValueError('bottom cannot be >= top')
#
# ValueError: left cannot be >= right
